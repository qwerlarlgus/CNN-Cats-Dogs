# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/CNN-Cats-Dogs/blob/main/3_batchnorm_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
# !ls -l
# Out:
# total 110548
# drwx------ 5 root root      4096 Jan 22 05:23 drive
# drwxr-xr-x 1 root root      4096 Jan 20 17:27 sample_data
# drwxr-xr-x 2 root root     36864 Jan 22 05:24 test_data
# drwxr-xr-x 2 root root     90112 Jan 22 05:24 training_data
# -rw------- 1 root root 113023590 Jan 22 05:23 training_data.zip
# drwxr-xr-x 2 root root     36864 Jan 22 05:24 validation_data

# %%
# !cp ./drive/MyDrive/training_data.zip .

# %%
# !unzip training_data.zip

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

# %%
IMG_DIM = (150, 150)

train_files = glob.glob('training_data/*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [fn.split('/')[1].split('.')[0].strip() for fn in train_files]

validation_files = glob.glob('validation_data/*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
validation_labels = [fn.split('/')[1].split('.')[0].strip() for fn in validation_files]

print('Train dataset shape:', train_imgs.shape, 
      '\tValidation dataset shape:', validation_imgs.shape)
# Out:
# Train dataset shape: (3000, 150, 150, 3) 	Validation dataset shape: (1000, 150, 150, 3)

# %%
train_imgs_scaled = train_imgs.astype('float32')
validation_imgs_scaled  = validation_imgs.astype('float32')
train_imgs_scaled /= 255
validation_imgs_scaled /= 255

# %%
print(train_imgs[99].shape)
array_to_img(train_imgs[99])
# Out:
# (150, 150, 3)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FAABA9339E8>

# %%
batch_size = 50
num_classes = 2
epochs = 150
input_shape = (150, 150, 3)

# encode text category labels
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[1495:1505], train_labels_enc[1495:1505])
# Out:
# ['dog', 'cat', 'cat', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat'] [1 0 0 0 0 1 1 0 1 0]

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

# %% [markdown]
# ### Model Case I

# %%
model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation='relu', padding="same",
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.3))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.2))
model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.15))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(rate = 0.1))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer= 'ADAM', # optimizers.RMSprop(lr=0.0001)
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        9280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 37, 37, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               21234176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 21,319,041
# Trainable params: 21,318,657
# Non-trainable params: 384
# _________________________________________________________________

# %%
history = model.fit(x=train_imgs_scaled, y=train_labels_enc,
                    validation_data=(validation_imgs_scaled, validation_labels_enc),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1)
# Out:
# Epoch 1/150
# 60/60 [==============================] - 10s 50ms/step - loss: 2.4806 - accuracy: 0.5446 - val_loss: 0.7539 - val_accuracy: 0.5120
# Epoch 2/150
# 60/60 [==============================] - 3s 42ms/step - loss: 0.6279 - accuracy: 0.6557 - val_loss: 0.8149 - val_accuracy: 0.5370
# Epoch 3/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0
150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0484 - accuracy: 0.9881 - val_loss: 4.0698 - val_accuracy: 0.6900
# Epoch 92/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0172 - accuracy: 0.9935 - val_loss: 3.2478 - val_accuracy: 0.7110
# Epoch 93/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0127 - accuracy: 0.9973 - val_loss: 3.1028 - val_accuracy: 0.6900
# Epoch 94/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0174 - accuracy: 0.9924 - val_loss: 2.3229 - val_accuracy: 0.7280
# Epoch 95/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0207 - accuracy: 0.9928 - val_loss: 2.8442 - val_accuracy: 0.7190
# Epoch 96/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0122 - accuracy: 0.9961 - val_loss: 2.7154 - val_accuracy: 0.7140
# Epoch 97/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 2.5426 - val_accuracy: 0.7220
# Epoch 98/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 2.5006 - val_accuracy: 0.7320
# Epoch 99/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0113 - accuracy: 0.9977 - val_loss: 3.0612 - val_accuracy: 0.7120
# Epoch 100/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0226 - accuracy: 0.9938 - val_loss: 3.1220 - val_accuracy: 0.7280
# Epoch 101/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0141 - accuracy: 0.9942 - val_loss: 2.5336 - val_accuracy: 0.7450
# Epoch 102/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0149 - accuracy: 0.9945 - val_loss: 3.7715 - val_accuracy: 0.6900
# Epoch 103/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 2.6315 - val_accuracy: 0.7330
# Epoch 104/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 3.4615 - val_accuracy: 0.7240
# Epoch 105/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0106 - accuracy: 0.9974 - val_loss: 3.5201 - val_accuracy: 0.7110
# Epoch 106/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0139 - accuracy: 0.9956 - val_loss: 3.5962 - val_accuracy: 0.7210
# Epoch 107/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0099 - accuracy: 0.9962 - val_loss: 3.1097 - val_accuracy: 0.7170
# Epoch 108/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0076 - accuracy: 0.9966 - val_loss: 3.0009 - val_accuracy: 0.7170
# Epoch 109/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0113 - accuracy: 0.9954 - val_loss: 2.9186 - val_accuracy: 0.7310
# Epoch 110/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0049 - accuracy: 0.9984 - val_loss: 2.9258 - val_accuracy: 0.7220
# Epoch 111/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0145 - accuracy: 0.9959 - val_loss: 3.7735 - val_accuracy: 0.7200
# Epoch 112/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0133 - accuracy: 0.9960 - val_loss: 3.4903 - val_accuracy: 0.7200
# Epoch 113/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0306 - accuracy: 0.9911 - val_loss: 3.1111 - val_accuracy: 0.6780
# Epoch 114/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0337 - accuracy: 0.9891 - val_loss: 3.4534 - val_accuracy: 0.7020
# Epoch 115/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0218 - accuracy: 0.9921 - val_loss: 3.8886 - val_accuracy: 0.7240
# Epoch 116/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0160 - accuracy: 0.9935 - val_loss: 4.3385 - val_accuracy: 0.7310
# Epoch 117/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0098 - accuracy: 0.9964 - val_loss: 3.7334 - val_accuracy: 0.7400
# Epoch 118/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0190 - accuracy: 0.9962 - val_loss: 2.6251 - val_accuracy: 0.7190
# Epoch 119/150
# 60/60 [==============================] - 3s 45ms/step - loss: 0.0287 - accuracy: 0.9898 - val_loss: 3.7068 - val_accuracy: 0.7180
# Epoch 120/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 3.2641 - val_accuracy: 0.7390
# Epoch 121/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0110 - accuracy: 0.9961 - val_loss: 3.5438 - val_accuracy: 0.7260
# Epoch 122/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0089 - accuracy: 0.9953 - val_loss: 2.8994 - val_accuracy: 0.7370
# Epoch 123/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0160 - accuracy: 0.9948 - val_loss: 2.9586 - val_accuracy: 0.7340
# Epoch 124/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0046 - accuracy: 0.9975 - val_loss: 3.4892 - val_accuracy: 0.7260
# Epoch 125/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0069 - accuracy: 0.9954 - val_loss: 3.3015 - val_accuracy: 0.7330
# Epoch 126/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0691 - accuracy: 0.9917 - val_loss: 5.2904 - val_accuracy: 0.6470
# Epoch 127/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0352 - accuracy: 0.9906 - val_loss: 2.8432 - val_accuracy: 0.7310
# Epoch 128/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0176 - accuracy: 0.9922 - val_loss: 3.6991 - val_accuracy: 0.7030
# Epoch 129/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0106 - accuracy: 0.9975 - val_loss: 3.3685 - val_accuracy: 0.7180
# Epoch 130/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0194 - accuracy: 0.9949 - val_loss: 3.4783 - val_accuracy: 0.6990
# Epoch 131/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0285 - accuracy: 0.9921 - val_loss: 3.5617 - val_accuracy: 0.7170
# Epoch 132/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 2.4473 - val_accuracy: 0.7400
# Epoch 133/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0127 - accuracy: 0.9965 - val_loss: 3.1412 - val_accuracy: 0.7270
# Epoch 134/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0061 - accuracy: 0.9976 - val_loss: 3.4705 - val_accuracy: 0.7480
# Epoch 135/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0135 - accuracy: 0.9970 - val_loss: 3.9465 - val_accuracy: 0.6870
# Epoch 136/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0170 - accuracy: 0.9970 - val_loss: 3.2798 - val_accuracy: 0.7170
# Epoch 137/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0125 - accuracy: 0.9951 - val_loss: 4.3926 - val_accuracy: 0.7020
# Epoch 138/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0150 - accuracy: 0.9965 - val_loss: 3.6467 - val_accuracy: 0.7300
# Epoch 139/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 3.1903 - val_accuracy: 0.7400
# Epoch 140/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0510 - accuracy: 0.9945 - val_loss: 3.6361 - val_accuracy: 0.7240
# Epoch 141/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0246 - accuracy: 0.9944 - val_loss: 5.8683 - val_accuracy: 0.6630
# Epoch 142/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0141 - accuracy: 0.9969 - val_loss: 3.7815 - val_accuracy: 0.7160
# Epoch 143/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0179 - accuracy: 0.9946 - val_loss: 4.2613 - val_accuracy: 0.7210
# Epoch 144/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0168 - accuracy: 0.9960 - val_loss: 4.4609 - val_accuracy: 0.7220
# Epoch 145/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0222 - accuracy: 0.9967 - val_loss: 5.4549 - val_accuracy: 0.6800
# Epoch 146/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0108 - accuracy: 0.9947 - val_loss: 3.8890 - val_accuracy: 0.7320
# Epoch 147/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0145 - accuracy: 0.9962 - val_loss: 2.9757 - val_accuracy: 0.7350
# Epoch 148/150
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0162 - accuracy: 0.9953 - val_loss: 3.8965 - val_accuracy: 0.7280
# Epoch 149/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0160 - accuracy: 0.9972 - val_loss: 3.4221 - val_accuracy: 0.7230
# Epoch 150/150
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0042 - accuracy: 0.9988 - val_loss: 4.3129 - val_accuracy: 0.7200

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,151))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 151, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 151, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save('2-2-batchnorm-cnn.h5')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
