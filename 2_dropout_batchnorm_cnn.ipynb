# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/CNN-Cats-Dogs/blob/main/2_dropout_batchnorm_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
# !ls -l
# Out:
# total 8
# drwx------ 5 root root 4096 Jan 22 04:53 drive
# drwxr-xr-x 1 root root 4096 Jan 20 17:27 sample_data

# %%
# !cp ./drive/MyDrive/training_data.zip .

# %%
# !unzip training_data.zip

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

# %%
IMG_DIM = (150, 150)

train_files = glob.glob('training_data/*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [fn.split('/')[1].split('.')[0].strip() for fn in train_files]

validation_files = glob.glob('validation_data/*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
validation_labels = [fn.split('/')[1].split('.')[0].strip() for fn in validation_files]

print('Train dataset shape:', train_imgs.shape, 
      '\tValidation dataset shape:', validation_imgs.shape)
# Out:
# Train dataset shape: (3000, 150, 150, 3) 	Validation dataset shape: (1000, 150, 150, 3)

# %%
train_imgs_scaled = train_imgs.astype('float32')
validation_imgs_scaled  = validation_imgs.astype('float32')
train_imgs_scaled /= 255
validation_imgs_scaled /= 255

# %%
print(train_imgs[99].shape)
array_to_img(train_imgs[99])
# Out:
# (150, 150, 3)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7F58F613D8D0>

# %%
batch_size = 50
num_classes = 2
epochs = 150
input_shape = (150, 150, 3)

# encode text category labels
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[1495:1505], train_labels_enc[1495:1505])
# Out:
# ['dog', 'cat', 'cat', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat'] [1 0 0 0 0 1 1 0 1 0]

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

# %% [markdown]
# ### Model Case I

# %%
model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation='relu', padding="same",
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.3))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.2))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.15))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(rate = 0.1))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer= 'ADAM', # optimizers.RMSprop(lr=0.0001)
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        9280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               21234176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 21,318,273
# Trainable params: 21,318,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=train_imgs_scaled, y=train_labels_enc,
                    validation_data=(validation_imgs_scaled, validation_labels_enc),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1)
# Out:
# Epoch 1/150
# 60/60 [==============================] - 10s 45ms/step - loss: 1.8410 - accuracy: 0.4873 - val_loss: 0.6893 - val_accuracy: 0.5650
# Epoch 2/150
# 60/60 [==============================] - 2s 39ms/step - loss: 0.6876 - accuracy: 0.5634 - val_loss: 0.6798 - val_accuracy: 0.5600
# Epoch 3/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.6721 - accuracy: 0.5813 - val_loss: 0.6804 - val_accuracy: 0.5640
# Epoch 4/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.6620 - accuracy: 0.6104 - val_loss: 0.6412 - val_accuracy: 0.6240
# Epoch 5/150
# 60/60 [==============================] - 2s 39ms/step - loss: 0.5946 - accuracy: 0.6749 - val_loss: 0.6289 - val_accuracy: 0.6590
# Epoch 6/150
# 60/60 [==============================] - 2s 39ms/step - loss: 0.5403 - accuracy: 0.7274 - val_loss: 0.6064 - val_accuracy: 0.6870
# Epoch 7/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.4874 - accuracy: 0.7595 - val_loss: 0.5881 - val_accuracy: 0.7210
# Epoch 8/150
# 60/60 [==============================] - 2s 39ms/step - loss: 0.4176 - accuracy: 0.8040 - val_loss: 0.6380 - val_accuracy: 0.7060
# Epoch 9/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.3447 - accuracy: 0.8429 - val_loss: 0.6521 - val_accuracy: 0.6990
# Epoch 10/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.3004 - accuracy: 0.8678 - val_loss: 0.6749 - val_accuracy: 0.7280
# Epoch 11/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.2283 - accuracy: 0.8963 - val_loss: 0.9167 - val_accuracy: 0.6970
# Epoch 12/150
# 60/60 [==============================] - 2s 39ms/step - loss: 0.1818 - accuracy: 0.9264 - val_loss: 0.8746 - val_accuracy: 0.7040
# Epoch 13/150
# 60/60 [==============================] - 2s 39ms/step - loss: 0.1210 - accuracy: 0.9541 - val_loss: 0.9320 - val_accuracy: 0.7010
# Epoch 14/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.1060 - accuracy: 0.9673 - val_loss: 1.1480 - val_accuracy: 0.6840
# Epoch 15/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.1014 - accuracy: 0.9703 - val_loss: 1.1776 - val_accuracy: 0.6880
# Epoch 16/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0573 - accuracy: 0.9853 - val_loss: 1.4768 - val_accuracy: 0.6900
# Epoch 17/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0517 - accuracy: 0.9853 - val_loss: 1.3217 - val_accuracy: 0.6760
# Epoch 18/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0526 - accuracy: 0.9859 - val_loss: 1.3204 - val_accuracy: 0.6990
# Epoch 19/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0282 - accuracy: 0.9934 - val_loss: 1.4618 - val_accuracy: 0.6870
# Epoch 20/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0348 - accuracy: 0.9921 - val_loss: 1.5745 - val_accuracy: 0.6960
# Epoch 21/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0458 - accuracy: 0.9873 - val_loss: 1.4911 - val_accuracy: 0.6840
# Epoch 22/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0249 - accuracy: 0.9927 - val_loss: 1.5035 - val_accuracy: 0.6940
# Epoch 23/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0145 - accuracy: 0.9975 - val_loss: 1.8205 - val_accuracy: 0.6890
# Epoch 24/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0142 - accuracy: 0.9974 - val_loss: 1.7628 - val_accuracy: 0.6940
# Epoch 25/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0206 - accuracy: 0.9933 - val_loss: 1.8396 - val_accuracy: 0.6940
# Epoch 26/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0132 - accuracy: 0.9946 - val_loss: 1.7864 - val_accuracy: 0.6930
# Epoch 27/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0157 - accuracy: 0.9943 - val_loss: 1.5326 - val_accuracy: 0.6800
# Epoch 28/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0189 - accuracy: 0.9949 - val_loss: 1.6555 - val_accuracy: 0.6850
# Epoch 29/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0067 - accuracy: 0.9996 - val_loss: 1.8611 - val_accuracy: 0.6910
# Epoch 30/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0053 - accuracy: 0.9980 - val_loss: 1.8549 - val_accuracy: 0.6860
# Epoch 31/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0038 - accuracy: 0.9998 - val_loss: 1.9520 - val_accuracy: 0.6930
# Epoch 32/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0041 - accuracy: 0.9994 - val_loss: 2.0807 - val_accuracy: 0.6890
# Epoch 33/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0059 - accuracy: 0.9996 - val_loss: 2.0042 - val_accuracy: 0.6940
# Epoch 34/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0082 - accuracy: 0.9982 - val_loss: 2.2852 - val_accuracy: 0.6990
# Epoch 35/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0114 - accuracy: 0.9949 - val_loss: 2.0320 - val_accuracy: 0.6750
# Epoch 36/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0090 - accuracy: 0.9977 - val_loss: 2.1545 - val_accuracy: 0.6900
# Epoch 37/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0250 - accuracy: 0.9931 - val_loss: 1.8537 - val_accuracy: 0.6650
# Epoch 38/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0170 - accuracy: 0.9933 - val_loss: 1.8495 - val_accuracy: 0.6970
# Epoch 39/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0204 - accuracy: 0.9933 - val_loss: 1.8566 - val_accuracy: 0.6950
# Epoch 40/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0135 - accuracy: 0.9957 - val_loss: 1.8914 - val_accuracy: 0.6930
# Epoch 41/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0195 - accuracy: 0.9946 - val_loss: 1.9023 - val_accuracy: 0.6910
# Epoch 42/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0219 - accuracy: 0.9936 - val_loss: 1.8665 - val_accuracy: 0.6950
# Epoch 43/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0112 - accuracy: 0.9951 - val_loss: 1.8592 - val_accuracy: 0.6980
# Epoch 44/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0065 - accuracy: 0.9985 - val_loss: 1.9602 - val_accuracy: 0.6870
# Epoch 45/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0067 - accuracy: 0.9977 - val_loss: 1.8847 - val_accuracy: 0.6960
# Epoch 46/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0111 - accuracy: 0.9958 - val_loss: 2.0012 - val_accuracy: 0.7100
# Epoch 47/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0089 - accuracy: 0.9976 - val_loss: 2.0946 - val_accuracy: 0.6970
# Epoch 48/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0019 - accuracy: 0.9999 - val_loss: 2.3754 - val_accuracy: 0.6900
# Epoch 49/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0079 - accuracy: 0.9979 - val_loss: 2.1155 - val_accuracy: 0.7080
# Epoch 50/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0027 - accuracy: 0.9984 - val_loss: 2.1201 - val_accuracy: 0.6970
# Epoch 51/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0025 - accuracy: 0.9995 - val_loss: 2.1518 - val_accuracy: 0.7020
# Epoch 52/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 2.2225 - val_accuracy: 0.7050
# Epoch 53/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0040 - accuracy: 0.9986 - val_loss: 2.2960 - val_accuracy: 0.6970
# Epoch 54/150
# 60/60 [==============================] - 2s 41ms/step - loss: 5.7099e-04 - accuracy: 1.0000 - val_loss: 2.2954 - val_accuracy: 0.6950
# Epoch 55/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 2.3340 - val_accuracy: 0.6820
# Epoch 56/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0041 - accuracy: 0.9988 - val_loss: 2.4848 - val_accuracy: 0.6890
# Epoch 57/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 2.3976 - val_accuracy: 0.6880
# Epoch 58/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0157 - accuracy: 0.9950 - val_loss: 2.1096 - val_accuracy: 0.6740
# Epoch 59/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0226 - accuracy: 0.9950 - val_loss: 2.0280 - val_accuracy: 0.6760
# Epoch 60/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0158 - accuracy: 0.9972 - val_loss: 2.1553 - val_accuracy: 0.6890
# Epoch 61/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0121 - accuracy: 0.9966 - val_loss: 2.1603 - val_accuracy: 0.7180
# Epoch 62/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0100 - accuracy: 0.9955 - val_loss: 2.1299 - val_accuracy: 0.7020
# Epoch 63/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0077 - accuracy: 0.9972 - val_loss: 2.0775 - val_accuracy: 0.6690
# Epoch 64/150
# 60/60 [==============================] - 3s 42ms/step - loss: 0.0083 - accuracy: 0.9982 - val_loss: 2.2306 - val_accuracy: 0.7000
# Epoch 65/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0043 - accuracy: 0.9987 - val_loss: 2.0455 - val_accuracy: 0.7010
# Epoch 66/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0023 - accuracy: 0.9994 - val_loss: 2.4350 - val_accuracy: 0.6750
# Epoch 67/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0146 - accuracy: 0.9944 - val_loss: 2.5141 - val_accuracy: 0.6890
# Epoch 68/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0044 - accuracy: 0.9995 - val_loss: 2.4453 - val_accuracy: 0.6890
# Epoch 69/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0044 - accuracy: 0.9992 - val_loss: 2.5913 - val_accuracy: 0.6770
# Epoch 70/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0031 - accuracy: 0.9986 - val_loss: 2.6492 - val_accuracy: 0.7000
# Epoch 71/150
# 60/60 [==============================] - 2s 40ms/step - loss: 0.
150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0011 - accuracy: 0.9998 - val_loss: 2.4860 - val_accuracy: 0.6560
# Epoch 124/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0359 - accuracy: 0.9899 - val_loss: 3.1997 - val_accuracy: 0.6920
# Epoch 125/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0578 - accuracy: 0.9870 - val_loss: 2.6408 - val_accuracy: 0.6920
# Epoch 126/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0305 - accuracy: 0.9918 - val_loss: 2.8253 - val_accuracy: 0.6840
# Epoch 127/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0080 - accuracy: 0.9944 - val_loss: 2.5574 - val_accuracy: 0.6750
# Epoch 128/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0024 - accuracy: 0.9986 - val_loss: 2.4747 - val_accuracy: 0.6800
# Epoch 129/150
# 60/60 [==============================] - 2s 42ms/step - loss: 0.0026 - accuracy: 0.9991 - val_loss: 2.4672 - val_accuracy: 0.6820
# Epoch 130/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 2.6557 - val_accuracy: 0.6940
# Epoch 131/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 2.9324 - val_accuracy: 0.6790
# Epoch 132/150
# 60/60 [==============================] - 2s 42ms/step - loss: 0.0014 - accuracy: 0.9999 - val_loss: 2.7353 - val_accuracy: 0.7030
# Epoch 133/150
# 60/60 [==============================] - 2s 41ms/step - loss: 8.6898e-04 - accuracy: 1.0000 - val_loss: 2.7112 - val_accuracy: 0.7030
# Epoch 134/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0010 - accuracy: 0.9996 - val_loss: 2.8189 - val_accuracy: 0.6910
# Epoch 135/150
# 60/60 [==============================] - 2s 41ms/step - loss: 2.8486e-04 - accuracy: 1.0000 - val_loss: 2.8475 - val_accuracy: 0.6960
# Epoch 136/150
# 60/60 [==============================] - 2s 41ms/step - loss: 2.3811e-04 - accuracy: 1.0000 - val_loss: 2.8757 - val_accuracy: 0.7010
# Epoch 137/150
# 60/60 [==============================] - 2s 41ms/step - loss: 1.3367e-04 - accuracy: 1.0000 - val_loss: 2.8886 - val_accuracy: 0.6990
# Epoch 138/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 3.1149 - val_accuracy: 0.6780
# Epoch 139/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0116 - accuracy: 0.9958 - val_loss: 3.0200 - val_accuracy: 0.6960
# Epoch 140/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0056 - accuracy: 0.9987 - val_loss: 3.1727 - val_accuracy: 0.6970
# Epoch 141/150
# 60/60 [==============================] - 2s 41ms/step - loss: 5.9778e-04 - accuracy: 1.0000 - val_loss: 3.1013 - val_accuracy: 0.7060
# Epoch 142/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0064 - accuracy: 0.9984 - val_loss: 3.1041 - val_accuracy: 0.6780
# Epoch 143/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0191 - accuracy: 0.9963 - val_loss: 2.7986 - val_accuracy: 0.6890
# Epoch 144/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0086 - accuracy: 0.9987 - val_loss: 2.6377 - val_accuracy: 0.6980
# Epoch 145/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0054 - accuracy: 0.9983 - val_loss: 3.0556 - val_accuracy: 0.6810
# Epoch 146/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 2.7490 - val_accuracy: 0.7100
# Epoch 147/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 2.1432 - val_accuracy: 0.6900
# Epoch 148/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0018 - accuracy: 0.9997 - val_loss: 2.9231 - val_accuracy: 0.6810
# Epoch 149/150
# 60/60 [==============================] - 2s 42ms/step - loss: 0.0022 - accuracy: 0.9995 - val_loss: 3.0179 - val_accuracy: 0.6940
# Epoch 150/150
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0036 - accuracy: 0.9990 - val_loss: 3.2763 - val_accuracy: 0.6760

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,151))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 151, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 151, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save('2-dropout-batchnorm-cnn.h5')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
