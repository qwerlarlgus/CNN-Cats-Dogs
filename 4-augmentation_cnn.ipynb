# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/CNN-Cats-Dogs/blob/main/3_aug_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
# !ls -l
# Out:
# total 8
# drwx------ 5 root root 4096 Jan 22 05:45 drive
# drwxr-xr-x 1 root root 4096 Jan 20 17:27 sample_data

# %%
# !cp ./drive/MyDrive/training_data.zip .

# %%
# !unzip training_data.zip

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

# %%
IMG_DIM = (150, 150)

train_files = glob.glob('training_data/*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [fn.split('/')[1].split('.')[0].strip() for fn in train_files]

validation_files = glob.glob('validation_data/*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
validation_labels = [fn.split('/')[1].split('.')[0].strip() for fn in validation_files]

print('Train dataset shape:', train_imgs.shape, 
      '\tValidation dataset shape:', validation_imgs.shape)
# Out:
# Train dataset shape: (3000, 150, 150, 3) 	Validation dataset shape: (1000, 150, 150, 3)

# %%
train_imgs_scaled = train_imgs.astype('float32')
validation_imgs_scaled  = validation_imgs.astype('float32')
train_imgs_scaled /= 255
validation_imgs_scaled /= 255

# %%
print(train_imgs[99].shape)
array_to_img(train_imgs[99])
# Out:
# (150, 150, 3)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FA51FC11400>

# %%
batch_size = 50
num_classes = 2
epochs = 150
input_shape = (150, 150, 3)

# encode text category labels
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[1495:1505], train_labels_enc[1495:1505])
# Out:
# ['dog', 'cat', 'cat', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat'] [1 0 0 0 0 1 1 0 1 0]

# %%
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, rotation_range=30,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')

# %%
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_id = 1000
cat_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
cat = [next(cat_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in cat])
l = [ax[i].imshow(cat[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['cat', 'cat', 'cat', 'cat', 'cat']

# %%
img_id = 1991
dog_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
dog = [next(dog_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(15, 6))
print('Labels:', [item[1][0] for item in dog])
l = [ax[i].imshow(dog[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['cat', 'cat', 'cat', 'cat', 'cat']

# %%
train_generator = train_datagen.flow(train_imgs, train_labels_enc, batch_size=32)
val_generator = val_datagen.flow(validation_imgs, validation_labels_enc, batch_size=16)

input_shape = (150, 150, 3)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

# %% [markdown]
# ### Model Case I

# %%
model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation='relu', padding="same",
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.3))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.2))
model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.15))
model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(Dropout(0.3))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(rate = 0.1))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer= 'ADAM', # optimizers.RMSprop(lr=0.0001)
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        9280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 37, 37, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16, 16, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               4194816
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 4,689,921
# Trainable params: 4,689,537
# Non-trainable params: 384
# _________________________________________________________________

# %%
history = model.fit_generator(train_generator,  epochs=epochs,
                              validation_data=val_generator,  verbose=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/150
# 94/94 [==============================] - 23s 161ms/step - loss: 2.7941 - accuracy: 0.4865 - val_loss: 0.6925 - val_accuracy: 0.5000
# Epoch 2/150
# 94/94 [==============================] - 15s 157ms/step - loss: 0.7024 - accuracy: 0.5276 - val_loss: 0.6863 - val_accuracy: 0.5010
# Epoch 3/150
# 94/94 [==============================] - 15s 158ms/step - loss: 0.6740 - accuracy: 0.5838 - val_loss: 0.6863 - val_accuracy: 0.5000
# Epoch 4/150
# 94/94 [==============================] - 15s 157ms/step - loss: 0.6720 - accuracy: 0.5749 - val_loss: 0.6924 - val_accuracy: 0.5210
# Epoch 5/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6950 - accuracy: 0.5016 - val_loss: 0.6919 - val_accuracy: 0.5130
# Epoch 6/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.6866 - accuracy: 0.5270 - val_loss: 0.6936 - val_accuracy: 0.5010
# Epoch 7/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6718 - accuracy: 0.5646 - val_loss: 0.6905 - val_accuracy: 0.5290
# Epoch 8/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6693 - accuracy: 0.5743 - val_loss: 0.6536 - val_accuracy: 0.6050
# Epoch 9/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.6610 - accuracy: 0.5743 - val_loss: 0.6732 - val_accuracy: 0.5710
# Epoch 10/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6689 - accuracy: 0.5665 - val_loss: 0.6795 - val_accuracy: 0.5730
# Epoch 11/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6666 - accuracy: 0.5679 - val_loss: 0.6983 - val_accuracy: 0.6090
# Epoch 12/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6654 - accuracy: 0.5863 - val_loss: 0.7690 - val_accuracy: 0.5820
# Epoch 13/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6632 - accuracy: 0.5830 - val_loss: 0.6472 - val_accuracy: 0.6290
# Epoch 14/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6695 - accuracy: 0.5688 - val_loss: 0.6510 - val_accuracy: 0.6230
# Epoch 15/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6664 - accuracy: 0.5965 - val_loss: 0.6555 - val_accuracy: 0.5980
# Epoch 16/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6527 - accuracy: 0.5865 - val_loss: 0.6703 - val_accuracy: 0.6240
# Epoch 17/150
# 94/94 [==============================] - 14s 154ms/step - loss: 0.6711 - accuracy: 0.5731 - val_loss: 0.6676 - val_accuracy: 0.5750
# Epoch 18/150
# 94/94 [==============================] - 14s 154ms/step - loss: 0.6670 - accuracy: 0.5795 - val_loss: 0.6682 - val_accuracy: 0.6350
# Epoch 19/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6581 - accuracy: 0.5846 - val_loss: 0.6706 - val_accuracy: 0.5620
# Epoch 20/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6573 - accuracy: 0.5851 - val_loss: 0.8140 - val_accuracy: 0.5870
# Epoch 21/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6565 - accuracy: 0.5862 - val_loss: 0.6973 - val_accuracy: 0.5000
# Epoch 22/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6708 - accuracy: 0.5687 - val_loss: 0.6872 - val_accuracy: 0.5370
# Epoch 23/150
# 94/94 [==============================] - 15s 157ms/step - loss: 0.6765 - accuracy: 0.5613 - val_loss: 0.6553 - val_accuracy: 0.6220
# Epoch 24/150
# 94/94 [==============================] - 15s 157ms/step - loss: 0.6578 - accuracy: 0.6074 - val_loss: 0.6482 - val_accuracy: 0.6110
# Epoch 25/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6661 - accuracy: 0.5751 - val_loss: 0.6482 - val_accuracy: 0.6340
# Epoch 26/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.6436 - accuracy: 0.6093 - val_loss: 0.6773 - val_accuracy: 0.5470
# Epoch 27/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6640 - accuracy: 0.5879 - val_loss: 0.6725 - val_accuracy: 0.5880
# Epoch 28/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6336 - accuracy: 0.6397 - val_loss: 0.6676 - val_accuracy: 0.5760
# Epoch 29/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.6485 - accuracy: 0.6197 - val_loss: 0.6901 - val_accuracy: 0.5400
# Epoch 30/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6501 - accuracy: 0.6075 - val_loss: 0.6229 - val_accuracy: 0.6540
# Epoch 31/150
# 94/94 [==============================] - 15s 157ms/step - loss: 0.6476 - accuracy: 0.6133 - val_loss: 0.9382 - val_accuracy: 0.5400
# Epoch 32/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6514 - accuracy: 0.6205 - val_loss: 0.6202 - val_accuracy: 0.6500
# Epoch 33/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6282 - accuracy: 0.6230 - val_loss: 0.6498 - val_accuracy: 0.6190
# Epoch 34/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6317 - accuracy: 0.6373 - val_loss: 0.6710 - val_accuracy: 0.5850
# Epoch 35/150
# 94/94 [==============================] - 15s 157ms/step - loss: 0.6248 - accuracy: 0.6514 - val_loss: 0.7094 - val_accuracy: 0.5860
# Epoch 36/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6248 - accuracy: 0.6410 - val_loss: 0.6967 - val_accuracy: 0.5500
# Epoch 37/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6759 - accuracy: 0.5865 - val_loss: 0.6580 - val_accuracy: 0.6130
# Epoch 38/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6595 - accuracy: 0.6032 - val_loss: 0.6315 - val_accuracy: 0.6530
# Epoch 39/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6500 - accuracy: 0.6124 - val_loss: 0.7607 - val_accuracy: 0.6170
# Epoch 40/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6493 - accuracy: 0.6219 - val_loss: 0.6444 - val_accuracy: 0.6160
# Epoch 41/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6510 - accuracy: 0.6158 - val_loss: 0.6352 - val_accuracy: 0.6370
# Epoch 42/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6428 - accuracy: 0.6226 - val_loss: 0.6453 - val_accuracy: 0.6390
# Epoch 43/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6356 - accuracy: 0.6339 - val_loss: 0.6457 - val_accuracy: 0.6250
# Epoch 44/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6473 - accuracy: 0.6182 - val_loss: 1.3165 - val_accuracy: 0.5160
# Epoch 45/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6490 - accuracy: 0.6225 - val_loss: 0.6281 - val_accuracy: 0.6420
# Epoch 46/150
# 94/94 [==============================] - 15s 157ms/step - loss: 0.6425 - accuracy: 0.6156 - val_loss: 0.6121 - val_accuracy: 0.6680
# Epoch 47/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6186 - accuracy: 0.6576 - val_loss: 0.6541 - val_accuracy: 0.6180
# Epoch 48/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6426 - accuracy: 0.6274 - val_loss: 0.6380 - val_accuracy: 0.6230
# Epoch 49/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6475 - accuracy: 0.6112 - val_loss: 0.6497 - val_accuracy: 0.6380
# Epoch 50/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6377 - accuracy: 0.6246 - val_loss: 0.6211 - val_accuracy: 0.6770
# Epoch 51/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6426 - accuracy: 0.6250 - val_loss: 0.6291 - val_accuracy: 0.6160
# Epoch 52/150
# 94/94 [==============================] - 15s 159ms/step - loss: 0.6078 - accuracy: 0.6600 - val_loss: 0.6792 - val_accuracy: 0.6230
# Epoch 53/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6159 - accuracy: 0.6548 - val_loss: 0.6100 - val_accuracy: 0.6680
# Epoch 54/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6208 - accuracy: 0.6503 - val_loss: 0.6436 - val_accuracy: 0.6430
# Epoch 55/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6681 - accuracy: 0.6057 - val_loss: 0.6512 - val_accuracy: 0.5540
# Epoch 56/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6530 - accuracy: 0.6067 - val_loss: 0.6364 - val_accuracy: 0.6410
# Epoch 57/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6364 - accuracy: 0.6289 - val_loss: 0.7730 - val_accuracy: 0.5910
# Epoch 58/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6158 - accuracy: 0.6530 - val_loss: 0.6092 - val_accuracy: 0.6650
# Epoch 59/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.6148 - accuracy: 0.6648 - val_loss: 0.6067 - val_accuracy: 0.6730
# Epoch 60/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6213 - accuracy: 0.6472 - val_loss: 0.6776 - val_accuracy: 0.6140
# Epoch 61/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6323 - accuracy: 0.6388 - val_loss: 0.6295 - val_accuracy: 0.6390
# Epoch 62/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6107 - accuracy: 0.6736 - val_loss: 0.6072 - val_accuracy: 0.6750
# Epoch 63/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6157 - accuracy: 0.6522 - val_loss: 0.5951 - val_accuracy: 0.7000
# Epoch 64/150
# 94/94 [==============================] - 14s 154ms/step - loss: 0.6098 - accuracy: 0.6690 - val_loss: 0.6002 - val_accuracy: 0.6750
# Epoch 65/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5951 - accuracy: 0.6669 - val_loss: 0.6101 - val_accuracy: 0.6640
# Epoch 66/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.6087 - accuracy: 0.6736 - val_loss: 0.6363 - val_accuracy: 0.6380
# Epoch 67/150
# 43/94 [============>.................] - ETA: 7s - loss: 0.6286 - accuracy: 0.6498

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,151))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 151, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 151, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save('3-aug-cnn.h5')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
