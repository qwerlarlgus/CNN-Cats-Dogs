# %% [markdown]
# <a href="https://colab.research.google.com/github/qwerlarlgus/CNN-Cats-Dogs/blob/main/%EC%A4%80%EB%B9%842_dropout_batchnorm_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
# !ls -l
# Out:
# total 111588
# drwx------ 4 root root      4096 Jan 25 02:56 drive
# drwxr-xr-x 1 root root      4096 Jan 20 17:27 sample_data
# -rw------- 1 root root 114250866 Jan 21 04:51 training_data.zip

# %%
# !cp ./drive/MyDrive/training_data.zip .
# Out:
# cp: cannot stat './drive/MyDrive/training_data.zip': No such file or directory

# %%
# !unzip training_data.zip

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

# %%
IMG_DIM = (150, 150)

train_files = glob.glob('training_data/*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [fn.split('/')[1].split('.')[0].strip() for fn in train_files]

validation_files = glob.glob('validation_data/*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
validation_labels = [fn.split('/')[1].split('.')[0].strip() for fn in validation_files]

print('Train dataset shape:', train_imgs.shape, 
      '\tValidation dataset shape:', validation_imgs.shape)
# Out:
# Train dataset shape: (3000, 150, 150, 3) 	Validation dataset shape: (1000, 150, 150, 3)

# %%
train_imgs_scaled = train_imgs.astype('float32')
validation_imgs_scaled  = validation_imgs.astype('float32')
train_imgs_scaled /= 255
validation_imgs_scaled /= 255

# %%
print(train_imgs[99].shape)
array_to_img(train_imgs[99])
# Out:
# (150, 150, 3)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FB88DDB18D0>

# %%
batch_size = 50
num_classes = 2
epochs = 150
input_shape = (150, 150, 3)

# encode text category labels
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[1495:1505], train_labels_enc[1495:1505])
# Out:
# ['dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'dog', 'cat', 'dog', 'dog'] [1 1 1 1 1 1 1 0 1 1]

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

# %% [markdown]
# ### Model Case I

# %%
model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation='relu', padding="same",
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.3))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.2))

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.15))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(rate = 0.1))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer= 'ADAM', # optimizers.RMSprop(lr=0.0001)
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        9280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               21234176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 21,318,273
# Trainable params: 21,318,273
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=train_imgs_scaled, y=train_labels_enc,
                    validation_data=(validation_imgs_scaled, validation_labels_enc),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1)
# Out:
# Epoch 1/150
# 60/60 [==============================] - 113s 2s/step - loss: 1.8663 - accuracy: 0.5098 - val_loss: 0.6876 - val_accuracy: 0.5080
# Epoch 2/150
# 60/60 [==============================] - 109s 2s/step - loss: 0.6749 - accuracy: 0.5443 - val_loss: 0.6781 - val_accuracy: 0.5720
# Epoch 3/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.6412 - accuracy: 0.6149 - val_loss: 0.6493 - val_accuracy: 0.6000
# Epoch 4/150
# 60/60 [==============================] - 113s 2s/step - loss: 0.6146 - accuracy: 0.6473 - val_loss: 0.6328 - val_accuracy: 0.6370
# Epoch 5/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.5883 - accuracy: 0.6817 - val_loss: 0.6161 - val_accuracy: 0.6530
# Epoch 6/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.5672 - accuracy: 0.6955 - val_loss: 0.6081 - val_accuracy: 0.6750
# Epoch 7/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.5185 - accuracy: 0.7348 - val_loss: 0.6020 - val_accuracy: 0.6840
# Epoch 8/150
# 60/60 [==============================] - 109s 2s/step - loss: 0.4812 - accuracy: 0.7534 - val_loss: 0.6330 - val_accuracy: 0.6820
# Epoch 9/150
# 60/60 [==============================] - 109s 2s/step - loss: 0.4777 - accuracy: 0.7702 - val_loss: 0.6305 - val_accuracy: 0.6990
# Epoch 10/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.4024 - accuracy: 0.8081 - val_loss: 0.6332 - val_accuracy: 0.6920
# Epoch 11/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.3501 - accuracy: 0.8399 - val_loss: 0.6687 - val_accuracy: 0.6910
# Epoch 12/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.3282 - accuracy: 0.8543 - val_loss: 0.7128 - val_accuracy: 0.7030
# Epoch 13/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.2547 - accuracy: 0.8877 - val_loss: 0.7239 - val_accuracy: 0.6890
# Epoch 14/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.2034 - accuracy: 0.9181 - val_loss: 0.9064 - val_accuracy: 0.6890
# Epoch 15/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.1522 - accuracy: 0.9407 - val_loss: 0.9694 - val_accuracy: 0.6930
# Epoch 16/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.1226 - accuracy: 0.9551 - val_loss: 1.1101 - val_accuracy: 0.6760
# Epoch 17/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0917 - accuracy: 0.9681 - val_loss: 1.1161 - val_accuracy: 0.6860
# Epoch 18/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0769 - accuracy: 0.9744 - val_loss: 1.2907 - val_accuracy: 0.6870
# Epoch 19/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0680 - accuracy: 0.9705 - val_loss: 1.1481 - val_accuracy: 0.6970
# Epoch 20/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0571 - accuracy: 0.9805 - val_loss: 1.2622 - val_accuracy: 0.7060
# Epoch 21/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0563 - accuracy: 0.9832 - val_loss: 1.4172 - val_accuracy: 0.6940
# Epoch 22/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0605 - accuracy: 0.9795 - val_loss: 1.3979 - val_accuracy: 0.7000
# Epoch 23/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0290 - accuracy: 0.9913 - val_loss: 1.7312 - val_accuracy: 0.6610
# Epoch 24/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0553 - accuracy: 0.9825 - val_loss: 1.4610 - val_accuracy: 0.6890
# Epoch 25/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0339 - accuracy: 0.9891 - val_loss: 1.5059 - val_accuracy: 0.6880
# Epoch 26/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0287 - accuracy: 0.9897 - val_loss: 1.6035 - val_accuracy: 0.6880
# Epoch 27/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0153 - accuracy: 0.9966 - val_loss: 1.8157 - val_accuracy: 0.6970
# Epoch 28/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0172 - accuracy: 0.9938 - val_loss: 1.6802 - val_accuracy: 0.6780
# Epoch 29/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0513 - accuracy: 0.9810 - val_loss: 1.5332 - val_accuracy: 0.6870
# Epoch 30/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0352 - accuracy: 0.9921 - val_loss: 1.6955 - val_accuracy: 0.6820
# Epoch 31/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0127 - accuracy: 0.9977 - val_loss: 1.8053 - val_accuracy: 0.6920
# Epoch 32/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0185 - accuracy: 0.9944 - val_loss: 1.9063 - val_accuracy: 0.6920
# Epoch 33/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0114 - accuracy: 0.9973 - val_loss: 1.9367 - val_accuracy: 0.6800
# Epoch 34/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0103 - accuracy: 0.9976 - val_loss: 2.0960 - val_accuracy: 0.6940
# Epoch 35/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0108 - accuracy: 0.9979 - val_loss: 1.8658 - val_accuracy: 0.6760
# Epoch 36/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0142 - accuracy: 0.9964 - val_loss: 2.0477 - val_accuracy: 0.6800
# Epoch 37/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0331 - accuracy: 0.9926 - val_loss: 1.7576 - val_accuracy: 0.6920
# Epoch 38/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0157 - accuracy: 0.9934 - val_loss: 2.1308 - val_accuracy: 0.6790
# Epoch 39/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0144 - accuracy: 0.9949 - val_loss: 2.0422 - val_accuracy: 0.6890
# Epoch 40/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0326 - accuracy: 0.9904 - val_loss: 1.7427 - val_accuracy: 0.6920
# Epoch 41/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0211 - accuracy: 0.9922 - val_loss: 1.8328 - val_accuracy: 0.7140
# Epoch 42/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0247 - accuracy: 0.9921 - val_loss: 1.7620 - val_accuracy: 0.6910
# Epoch 43/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 1.8995 - val_accuracy: 0.6990
# Epoch 44/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0176 - accuracy: 0.9942 - val_loss: 1.7642 - val_accuracy: 0.7020
# Epoch 45/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0129 - accuracy: 0.9965 - val_loss: 2.0143 - val_accuracy: 0.6730
# Epoch 46/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0065 - accuracy: 0.9989 - val_loss: 2.0201 - val_accuracy: 0.6800
# Epoch 47/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0049 - accuracy: 0.9983 - val_loss: 2.0839 - val_accuracy: 0.6910
# Epoch 48/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0052 - accuracy: 0.9993 - val_loss: 2.2056 - val_accuracy: 0.6920
# Epoch 49/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 2.2764 - val_accuracy: 0.6990
# Epoch 50/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0122 - accuracy: 0.9966 - val_loss: 1.8680 - val_accuracy: 0.6850
# Epoch 51/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0134 - accuracy: 0.9957 - val_loss: 2.1785 - val_accuracy: 0.6740
# Epoch 52/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0061 - accuracy: 0.9990 - val_loss: 2.3018 - val_accuracy: 0.6930
# Epoch 53/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 2.4179 - val_accuracy: 0.6970
# Epoch 54/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0184 - accuracy: 0.9955 - val_loss: 2.2380 - val_accuracy: 0.6920
# Epoch 55/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0139 - accuracy: 0.9961 - val_loss: 2.1448 - val_accuracy: 0.6870
# Epoch 56/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0121 - accuracy: 0.9971 - val_loss: 2.1136 - val_accuracy: 0.6770
# Epoch 57/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0078 - accuracy: 0.9975 - val_loss: 2.1271 - val_accuracy: 0.6890
# Epoch 58/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0103 - accuracy: 0.9974 - val_loss: 2.0929 - val_accuracy: 0.6920
# Epoch 59/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0134 - accuracy: 0.9959 - val_loss: 2.0519 - val_accuracy: 0.6820
# Epoch 60/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0251 - accuracy: 0.9934 - val_loss: 2.0211 - val_accuracy: 0.6760
# Epoch 61/150
# 60/60 [==============================] - 112s 2s/step - loss: 0.0102 - accuracy: 0.9972 - val_loss: 2.2129 - val_accuracy: 0.6890
# Epoch 62/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0069 - accuracy: 0.9990 - val_loss: 2.1713 - val_accuracy: 0.6630
# Epoch 63/150
# 60/60 [==============================] - 112s 2s/step - loss: 0.0135 - accuracy: 0.9965 - val_loss: 2.0823 - val_accuracy: 0.6800
# Epoch 64/150
# 60/60 [==============================] - 112s 2s/step - loss: 0.0073 - accuracy: 0.9961 - val_loss: 2.1260 - val_accuracy: 0.6880
# Epoch 65/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0026 - accuracy: 0.9997 - val_loss: 2.2201 - val_accuracy: 0.6750
# Epoch 66/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 2.5156 - val_accuracy: 0.6780
# Epoch 67/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0512 - accuracy: 0.9863 - val_loss: 1.9463 - val_accuracy: 0.6740
# Epoch 68/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0154 - accuracy: 0.9944 - val_loss: 2.1268 - val_accuracy: 0.6890
# Epoch 69/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0087 - accuracy: 0.9973 - val_loss: 2.2368 - val_accuracy: 0.6760
# Epoch 70/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0093 - accuracy: 0.9971 - val_loss: 2.3658 - val_accuracy: 0.6730
# Epoch 71/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0131 - accuracy: 0.9946 - val_loss: 2.0778 - val_accuracy: 0.6970
# Epoch 72/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0110 - accuracy: 0.9965 - val_loss: 2.1124 - val_accuracy: 0.6960
# Epoch 73/150
# 60/60 [==============================] - 110s 2s/step - loss: 0.0036 - accuracy: 0.9989 - val_loss: 2.4712 - val_accuracy: 0.6870
# Epoch 74/150
# 60/60 [==============================] - 111s 2s/step - loss: 0.0138 - accuracy: 0.9966 - val_loss: 2.1725 - val_accuracy: 0.7050
# Epoch 75/150
# 56/60 [===========================>..] - ETA: 6s - loss: 0.0033 - accuracy: 0.9983

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Basic CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

epoch_list = list(range(1,151))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(0, 151, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(0, 151, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")

# %%
model.save('2-dropout-batchnorm-cnn.h5')

# %%
from google.colab import drive
drive.mount('/content/drive')
