# %% [markdown]
# <a href="https://colab.research.google.com/github/JSJeong-me/CNN-Cats-Dogs/blob/main/3_2_aug_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline

# %%
# !ls -l
# Out:
# total 8
# drwx------ 5 root root 4096 Jan 22 06:46 drive
# drwxr-xr-x 1 root root 4096 Jan 20 17:27 sample_data

# %%
# !cp ./drive/MyDrive/training_data.zip .

# %%
# !unzip training_data.zip

# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array, array_to_img

# %%
IMG_DIM = (150, 150)

train_files = glob.glob('training_data/*')
train_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in train_files]
train_imgs = np.array(train_imgs)
train_labels = [fn.split('/')[1].split('.')[0].strip() for fn in train_files]

validation_files = glob.glob('validation_data/*')
validation_imgs = [img_to_array(load_img(img, target_size=IMG_DIM)) for img in validation_files]
validation_imgs = np.array(validation_imgs)
validation_labels = [fn.split('/')[1].split('.')[0].strip() for fn in validation_files]

print('Train dataset shape:', train_imgs.shape, 
      '\tValidation dataset shape:', validation_imgs.shape)
# Out:
# Train dataset shape: (3000, 150, 150, 3) 	Validation dataset shape: (1000, 150, 150, 3)

# %%
train_imgs_scaled = train_imgs.astype('float32')
validation_imgs_scaled  = validation_imgs.astype('float32')
train_imgs_scaled /= 255
validation_imgs_scaled /= 255

# %%
print(train_imgs[99].shape)
array_to_img(train_imgs[99])
# Out:
# (150, 150, 3)
# <PIL.Image.Image image mode=RGB size=150x150 at 0x7FD500D3C9B0>

# %%
batch_size = 50
num_classes = 2
epochs = 150
input_shape = (150, 150, 3)

# encode text category labels
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
le.fit(train_labels)
train_labels_enc = le.transform(train_labels)
validation_labels_enc = le.transform(validation_labels)

print(train_labels[1495:1505], train_labels_enc[1495:1505])
# Out:
# ['dog', 'cat', 'cat', 'cat', 'cat', 'dog', 'dog', 'cat', 'dog', 'cat'] [1 0 0 0 0 1 1 0 1 0]

# %%
train_datagen = ImageDataGenerator(rescale=1./255, zoom_range=0.3, rotation_range=30,
                                   width_shift_range=0.2, height_shift_range=0.2, shear_range=0.2, 
                                   horizontal_flip=True, fill_mode='nearest')

# %%
val_datagen = ImageDataGenerator(rescale=1./255)

# %%
img_id = 1000
cat_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
cat = [next(cat_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(16, 6))
print('Labels:', [item[1][0] for item in cat])
l = [ax[i].imshow(cat[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['cat', 'cat', 'cat', 'cat', 'cat']

# %%
img_id = 1991
dog_generator = train_datagen.flow(train_imgs[img_id:img_id+1], train_labels[img_id:img_id+1],
                                   batch_size=1)
dog = [next(dog_generator) for i in range(0,5)]
fig, ax = plt.subplots(1,5, figsize=(15, 6))
print('Labels:', [item[1][0] for item in dog])
l = [ax[i].imshow(dog[i][0][0]) for i in range(0,5)]
# Out:
# Labels: ['cat', 'cat', 'cat', 'cat', 'cat']

# %%
train_generator = train_datagen.flow(train_imgs, train_labels_enc, batch_size=32)
val_generator = val_datagen.flow(validation_imgs, validation_labels_enc, batch_size=16)

input_shape = (150, 150, 3)

# %%
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras import optimizers

# %% [markdown]
# ### Model Case I

# %%
model = Sequential()

model.add(Conv2D(16, kernel_size=(3, 3), activation='relu', padding="same",
                 input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.3))

model.add(Conv2D(64, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.2))
model.add(BatchNormalization())

model.add(Conv2D(128, kernel_size=(3, 3), activation='relu', padding="same"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate = 0.15))
model.add(BatchNormalization())
'''
model.add(Conv2D(128, kernel_size=(3, 3), activation='relu'))
model.add(Dropout(0.3))
model.add(MaxPooling2D(pool_size=(2, 2)))
'''
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(rate = 0.1))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',
              optimizer= 'ADAM', # optimizers.RMSprop(lr=0.0001)
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 16)      448
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 16)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 64)        9280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 37, 37, 64)        256
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       73856
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# flatten (Flatten)            (None, 41472)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               21234176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                32832
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 21,351,425
# Trainable params: 21,351,041
# Non-trainable params: 384
# _________________________________________________________________

# %%
history = model.fit_generator(train_generator,  epochs=epochs,
                              validation_data=val_generator,  verbose=1)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/150
# 94/94 [==============================] - 22s 160ms/step - loss: 1.4547 - accuracy: 0.5654 - val_loss: 0.7244 - val_accuracy: 0.5010
# Epoch 2/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6878 - accuracy: 0.5411 - val_loss: 0.7288 - val_accuracy: 0.4990
# Epoch 3/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6678 - accuracy: 0.5892 - val_loss: 0.8290 - val_accuracy: 0.5000
# Epoch 4/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6685 - accuracy: 0.5843 - val_loss: 0.7947 - val_accuracy: 0.5000
# Epoch 5/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6797 - accuracy: 0.5664 - val_loss: 0.7840 - val_accuracy: 0.5010
# Epoch 6/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6707 - accuracy: 0.5883 - val_loss: 0.8301 - val_accuracy: 0.4940
# Epoch 7/150
# 94/94 [==============================] - 15s 157ms/step - loss: 0.6526 - accuracy: 0.6122 - val_loss: 0.9003 - val_accuracy: 0.5320
# Epoch 8/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.6353 - accuracy: 0.6295 - val_loss: 0.6895 - val_accuracy: 0.5270
# Epoch 9/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6659 - accuracy: 0.5846 - val_loss: 0.6502 - val_accuracy: 0.5940
# Epoch 10/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6350 - accuracy: 0.6238 - val_loss: 0.7403 - val_accuracy: 0.5640
# Epoch 11/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6297 - accuracy: 0.6419 - val_loss: 0.6619 - val_accuracy: 0.6240
# Epoch 12/150
# 94/94 [==============================] - 14s 154ms/step - loss: 0.6229 - accuracy: 0.6619 - val_loss: 0.6036 - val_accuracy: 0.6780
# Epoch 13/150
# 94/94 [==============================] - 14s 153ms/step - loss: 0.6155 - accuracy: 0.6545 - val_loss: 0.7671 - val_accuracy: 0.5960
# Epoch 14/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6076 - accuracy: 0.6581 - val_loss: 0.6197 - val_accuracy: 0.6410
# Epoch 15/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6070 - accuracy: 0.6651 - val_loss: 0.5953 - val_accuracy: 0.6800
# Epoch 16/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6225 - accuracy: 0.6438 - val_loss: 0.9119 - val_accuracy: 0.5350
# Epoch 17/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6142 - accuracy: 0.6293 - val_loss: 0.6859 - val_accuracy: 0.6000
# Epoch 18/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6045 - accuracy: 0.6632 - val_loss: 0.7063 - val_accuracy: 0.6400
# Epoch 19/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.5910 - accuracy: 0.6765 - val_loss: 0.6427 - val_accuracy: 0.6850
# Epoch 20/150
# 94/94 [==============================] - 14s 154ms/step - loss: 0.5919 - accuracy: 0.6815 - val_loss: 0.5934 - val_accuracy: 0.6780
# Epoch 21/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.6122 - accuracy: 0.6650 - val_loss: 0.5854 - val_accuracy: 0.7000
# Epoch 22/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.5806 - accuracy: 0.6783 - val_loss: 0.6101 - val_accuracy: 0.6720
# Epoch 23/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.5852 - accuracy: 0.6674 - val_loss: 0.5989 - val_accuracy: 0.7000
# Epoch 24/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5866 - accuracy: 0.6838 - val_loss: 0.6609 - val_accuracy: 0.6770
# Epoch 25/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.5729 - accuracy: 0.6929 - val_loss: 0.6144 - val_accuracy: 0.6950
# Epoch 26/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5791 - accuracy: 0.6706 - val_loss: 1.0200 - val_accuracy: 0.6040
# Epoch 27/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.5701 - accuracy: 0.6992 - val_loss: 0.5424 - val_accuracy: 0.7220
# Epoch 28/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.5456 - accuracy: 0.7234 - val_loss: 0.7162 - val_accuracy: 0.7320
# Epoch 29/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.5913 - accuracy: 0.6992 - val_loss: 0.7645 - val_accuracy: 0.6150
# Epoch 30/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.5672 - accuracy: 0.7099 - val_loss: 0.5154 - val_accuracy: 0.7610
# Epoch 31/150
# 94/94 [==============================] - 15s 154ms/step - loss: 0.5558 - accuracy: 0.7129 - val_loss: 0.6387 - val_accuracy: 0.6470
# Epoch 32/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5562 - accuracy: 0.7269 - val_loss: 0.6017 - val_accuracy: 0.7000
# Epoch 33/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.5577 - accuracy: 0.7100 - val_loss: 0.5180 - val_accuracy: 0.7460
# Epoch 34/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5405 - accuracy: 0.7290 - val_loss: 0.7514 - val_accuracy: 0.6550
# Epoch 35/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5420 - accuracy: 0.7279 - val_loss: 0.5930 - val_accuracy: 0.7340
# Epoch 36/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5312 - accuracy: 0.7315 - val_loss: 0.7205 - val_accuracy: 0.6720
# Epoch 37/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5379 - accuracy: 0.7423 - val_loss: 0.6245 - val_accuracy: 0.7090
# Epoch 38/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.5420 - accuracy: 0.7240 - val_loss: 0.5068 - val_accuracy: 0.7550
# Epoch 39/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.5063 - accuracy: 0.7456 - val_loss: 0.5638 - val_accuracy: 0.7230
# Epoch 40/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5177 - accuracy: 0.7366 - val_loss: 0.5483 - val_accuracy: 0.7310
# Epoch 41/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.5421 - accuracy: 0.7165 - val_loss: 0.5835 - val_accuracy: 0.7070
# Epoch 42/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5171 - accuracy: 0.7488 - val_loss: 0.5303 - val_accuracy: 0.7280
# Epoch 43/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5291 - accuracy: 0.7410 - val_loss: 0.5067 - val_accuracy: 0.7450
# Epoch 44/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.4915 - accuracy: 0.7586 - val_loss: 0.6301 - val_accuracy: 0.6960
# Epoch 45/150
# 94/94 [==============================] - 15s 156ms/step - loss: 0.5120 - accuracy: 0.7515 - val_loss: 0.6064 - val_accuracy: 0.7340
# Epoch 46/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.4896 - accuracy: 0.7646 - val_loss: 0.5228 - val_accuracy: 0.7540
# Epoch 47/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.5068 - accuracy: 0.7460 - val_loss: 0.6921 - val_accuracy: 0.7080
# Epoch 48/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.4961 - accuracy: 0.7778 - val_loss: 0.4961 - val_accuracy: 0.7810
# Epoch 49/150
# 94/94 [==============================] - 15s 157ms/step - loss: 0.5179 - accuracy: 0.7674 - val_loss: 0.4560 - val_accuracy: 0.7780
# Epoch 50/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.4834 - accuracy: 0.7728 - val_loss: 0.6041 - val_accuracy: 0.7490
# Epoch 51/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.4870 - accuracy: 0.7607 - val_loss: 0.5675 - val_accuracy: 0.7680
# Epoch 52/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0.4786 - accuracy: 0.7802 - val_loss: 0.5042 - val_accuracy: 0.7500
# Epoch 53/150
# 94/94 [==============================] - 15s 155ms/step - loss: 0